# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv("/content/drive/MyDrive/youtubeprojects/youtubedataset/IN_youtube_trending_data.csv")

# %%
display(dataset)
# Out:
#            video_id                                              title  \
# 0       Iot0eF6EoNA  Sadak 2 | Official Trailer | Sanjay | Pooja | ...
# 1       x-KbnJ9fvJc  Kya Baat Aa : Karan Aujla (Official Video) Tan...
# 2       KX06ksuS6Xo  Diljit Dosanjh: CLASH (Official) Music Video |...
# 3       UsMRgnTcchY  Dil Ko Maine Di Kasam Video | Amaal M Ft.Ariji...
# 4       WNSEXJJhKTU  Baarish (Official Video) Payal Dev,Stebin Ben ...
# ...             ...                                                ...
# 213004  dajdDoCbDYg  Kundali Bhagya: OMG! Snake bites Kavya, Will R...
# 213005  SmnNWdo7ln0  ज़िंदगी की पहली Car 🥹 || Taking Delivery of FI...
# 213006  Cura8QlSsSA  We are going to INDIA? 🇮🇳 | Sistrology | Fatim...
# 213007  g-3vdP_Xh7I  MAD - Official Teaser | Kalyan Shankar | S. Na...
# 213008  FeCdCbI_jDQ  moto G84 5G Unboxing And First Impressions⚡Mos...
#
#                  publishedAt                 channelId  \
# 0       2020-08-12T04:31:41Z  UCGqvJPRcv7aVFun-eTsatcA
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213009 entries, 0 to 213008
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   video_id           213009 non-null  object
#  1   title              213009 non-null  object
#  2   publishedAt        213009 non-null  object
#  3   channelId          213009 non-null  object
#  4   channelTitle       213008 non-null  object
#  5   categoryId         213009 non-null  int64
#  6   trending_date      213009 non-null  object
#  7   tags               213009 non-null  object
#  8   view_count         213009 non-null  int64
#  9   likes              213009 non-null  int64
#  10  dislikes           213009 non-null  int64
#  11  comment_count      213009 non-null  int64
#  12  thumbnail_link     213009 non-null  object
#  13  comments_disabled  213009 non-null  bool
#  14  ratings_disabled   213009 non-null  bool
# ...

# %%
dataset.describe()
# Out:
#           categoryId    view_count         likes      dislikes  comment_count
# count  213009.000000  2.130090e+05  2.130090e+05  2.130090e+05   2.130090e+05
# mean       20.868761  2.913238e+06  1.484137e+05  2.752426e+03   8.865039e+03
# std         6.026084  7.128443e+06  4.065667e+05  7.819240e+04   7.555820e+04
# min         1.000000  0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00
# 25%        20.000000  4.071420e+05  1.378000e+04  0.000000e+00   3.700000e+02
# 50%        24.000000  1.005752e+06  4.150100e+04  0.000000e+00   1.209000e+03
# 75%        24.000000  2.557799e+06  1.263940e+05  1.058000e+03   4.227000e+03
# max        29.000000  2.644074e+08  1.611524e+07  1.234147e+07   6.738565e+06

# %%
dataset['likes'].plot(kind='box')
# Out:
# <Axes: >

# %%
dataset.isnull().sum()
# Out:
# video_id                 0
# title                    0
# publishedAt              0
# channelId                0
# channelTitle             1
# categoryId               0
# trending_date            0
# tags                     0
# view_count               0
# likes                    0
# dislikes                 0
# comment_count            0
# thumbnail_link           0
# comments_disabled        0
# ratings_disabled         0
# description          18151
# dtype: int64

# %%
dataset.nunique()
# Out:
# video_id              65788
# title                 66671
# publishedAt           65187
# channelId              4295
# channelTitle           4514
# categoryId               15
# trending_date          1101
# tags                  41667
# view_count           205473
# likes                124804
# dislikes              17039
# comment_count         30529
# thumbnail_link        65789
# comments_disabled         2
# ratings_disabled          2
# description           55659
# dtype: int64

# %%
dataset.duplicated().value_counts()
# Out:
# False    212934
# True         75
# dtype: int64

# %%
dataset.duplicated().sum()
# Out:
# 75

# %%
dataset = dataset.drop_duplicates()

# %%
dataset.duplicated().sum()
# Out:
# 0

# %% [markdown]
# 1. load dataset from google drive to google colab
#
# 2. first look of dataset
#
# 3. basic info of dataset
#
# 4. summary of numerical columns of dataset
#
# 5. Number of null values of dataset
#
# 6. Number of unique values of dataset
#
# 7. Number of duplicate rows of dataset
#
# 8. Duplicate rows removed

# %%
dataset.isnull().sum()
# Out:
# video_id                 0
# title                    0
# publishedAt              0
# channelId                0
# channelTitle             1
# categoryId               0
# trending_date            0
# tags                     0
# view_count               0
# likes                    0
# dislikes                 0
# comment_count            0
# thumbnail_link           0
# comments_disabled        0
# ratings_disabled         0
# description          18148
# dtype: int64
